# %% [raw]
# ---
# title: "What I'm reading currently"
# author: "Andrew Morrison"
# date: "2025-6-19"
# categories: [reading]
# format: html
# toc: true
# code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# I'm going to try to log some of my reading here - what I'm currently reading, what I've finished recently, what I might read next.  I'm not sure how this will work, but I want to give it a try.
#
# # What I recently finished reading

# %% [markdown]
# [<img src="https://m.media-amazon.com/images/S/compressed.photo.goodreads.com/books/1566187159l/52127888._SX600_.jpg" alt="Geeky Pedagogy book cover" width=150>](https://www.goodreads.com/book/show/52127888-geeky-pedagogy)
#
# _Geeky Pedagogy_ by Jessamyn Neuhaus
# This was a book club selection for a group of educators that met online every other week to discuss this book.  I thought it was a pretty good choice for the book club. This was the last book I finished in 2025
