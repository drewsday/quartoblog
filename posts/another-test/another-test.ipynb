# %% [raw]
# ---
# title: "Just trying the basics"
# author: "Andrew Morrison"
# date: "2025-6-12"
# categories: [test]
# format: html
# toc: true
# ---

# %% [markdown]
# # Heading
#
# And some text!

# %% [markdown]
# ## Adding something new
#
# This was added on 9/9/2025.
