# %% [raw]
# ---
# title: "Notes to Self for blog posting"
# author: "Andrew Morrison"
# date: "2023-8-7"
# categories: [test]
# format:
#   html:
#     toc: true
#     code-fold: true
# ---

# %% [markdown]
# # Last few things to remind myself
#
# When composing posts in the quarto blog here are some things I seem to frequently forget:
#
# - Lists have to be started with a blank line in the Jupyter notebook
# - I should be able to drag and drop an image file into the markdown cell and the proper markdown formating will be auto-generated.  See below:
#
# ![Finished RAGBRAI 2023 with my support team!](attachment:278676f2-4a8c-4d22-8c05-81e06391305f.jpeg)

# %% [markdown]
# # A few more things worth testing
#
# I should try figuring out the following items:
#
# - Testing embeds on blog posts, including:
#     + Youtube videos
#     + Other videos?
#     + Trinket.io code posts
#     + Mastodon/Bluesky posts
# - Including code cells in posts
# - Updating the theme
# - Updating the index page
# - Updating the About page

# %% [markdown]
# ## Testing Mastodon
#
# {{< mastodon "https://mastodon.social/@sellorm/109376707453406631" >}}
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
#
# Did it work? Yes!
#
# Can I see this?
