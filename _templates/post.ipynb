# %% [raw]
# ---
# title: "{{TITLE}}"
# author: "Andrew Morrison"
# date: "{{DATE}}"
# categories: []
# draft: true
# format:
#   html:
#     toc: true
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# Write the post here.
#
# Before publishing, delete `draft: true` from the raw cell above — while it is
# there the post renders locally but is kept off the site's listing. Add one or
# more `categories` too.
#
# Run any code cells before committing: their stored output is what gets
# published, since CI does not execute notebooks.
